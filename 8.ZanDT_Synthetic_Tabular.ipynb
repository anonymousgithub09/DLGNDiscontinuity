# %%
# !git clone https://github.com/anonymousgithub09/ZanDT.git

# %%
# !pip install qhoptim

# %%
# !python /kaggle/working/LatentTreePrithaj/tabular_classification.py "UCI" 4 1.4837286400170702 5 0.07041761417608994
